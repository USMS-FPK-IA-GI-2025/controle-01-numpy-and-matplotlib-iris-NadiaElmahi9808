# %% [markdown]
# <a href="https://colab.research.google.com/github/USMS-FPK-IA-GI-2025/controle01-numpy-matplotlib-iris/blob/main/notebooks/controle_numpy_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Contrôle 01 — Data Science avec NumPy et Matplotlib
# **Master 1 — Intelligence Artificielle & Génie Informatique (FPK / USMS)**
#
# Nom & Prénom :    **EL MAHI  NADIA**
# Filière :    **SIIA  , FPK**
# Année universitaire :      2025 \ 2026
#
# ---
#
# **Règles :**
# - Bibliothèques autorisées : NumPy, Matplotlib
# - Toute autre bibliothèque est interdite
# - Chaque question doit être traitée dans une cellule dédiée
# - Chaque résultat doit être brièvement interprété

# %% [markdown]
# # Partie A — Importation du Dataset, Arrays, Premières Manipulations

# %% [markdown]
# ### A1. Importation du dataset
# Importez NumPy et Matplotlib.
# Chargez le fichier `iris.csv` avec `np.genfromtxt` (`delimiter=','`, `skip_header=1`).
# Stockez les données dans un array nommé `data` et affichez sa `shape`.

# %%
import numpy as np
import matplotlib.pyplot as plt
#Charger le fichier
data = np.genfromtxt('data/Iris.csv', delimiter=',', dtype=str,skip_header=1)
print(f"Dimension de notre dataset :{data.shape}")
# Out:
# Dimension de notre dataset :(150, 6)

# %% [markdown]
# ### A2. Séparation des features et des espèces
# Séparez :
# - les 4 premières colonnes numériques dans un array `features`
# - la dernière colonne (espèces) dans un array `species`
# Utilisez le slicing.

# %%
features = data[:,1:5].astype(float) #toutes les lignes et 1--> 4 colonne car 1ere colonne c'est l'ID
species = data[:,-1] # Toutes les lignes et la derniere colonne
#verification
print(f"Dimension de features : {features.shape}")
print(f"Dimension de species : {species.shape}")
# Out:
# Dimension de features : (150, 4)
# Dimension de species : (150,)

# %% [markdown]
# ### A3. Indexing
# Affichez les 5 premières lignes de `features` en utilisant l’indexing.

# %%
#Lignes 0 --> 4
print(features[:5])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]

# %% [markdown]
# ### A4. Extraction d’une colonne
# Créez un array `sepal_length` contenant uniquement la première colonne de `features`.
# Affichez sa `size` et son `dtype`.

# %%
sepal_length = features[:, 0]   #1ere colonne index 0
print(f"Num total des elements dans sepal length : {sepal_length.size}")
print(f"Type de données de sepal length : {sepal_length.size}")
# Out:
# Num total des elements dans sepal length : 150
# Type de données de sepal length : 150

# %% [markdown]
# ### A5. Slicing par espèce
# Utilisez le slicing pour extraire les 50 premières lignes correspondant à l’espèce *Setosa*.
# Stockez-les dans `setosa_features`.

# %%
#Slicing 50 lignes
setosa_features = features[:50]
#Verification
print(f"Dimension de setosa_features : {setosa_features.shape}")
print(f"N elements dans setosa_features : {setosa_features.size}")
# Out:
# Dimension de setosa_features : (50, 4)
# N elements dans setosa_features : 200

# %% [markdown]
# # Partie B — Statistiques Basiques et Opérations Mathématiques

# %% [markdown]
# ### B6. Moyenne par colonne
# Calculez la moyenne de chaque colonne de `features` avec `np.mean(axis=0)`.

# %%
moyennes_col = np.mean(features, axis=0)
print(moyennes_col)
# Out:
# [5.84333333 3.054      3.75866667 1.19866667]

# %% [markdown]
# ### B7. Min et Max
# Trouvez la valeur minimale et maximale de la longueur des pétales.

# %%
#longueur des petales 3eme colonne dans features
petal_length=features[:,2]
min_petal=np.min(petal_length)
max_petal=np.max(petal_length)
print(f"Valeur min de longueur des petales : {min_petal}")
print(f"Valeur max de longueur des petales : {max_petal}")
# Out:
# Valeur min de longueur des petales : 1.0
# Valeur max de longueur des petales : 6.9

# %% [markdown]
# ### B9. Normalisation
# Normalisez les longueurs des pétales en les divisant par leur maximum.
# Stockez le résultat dans `normalized_petals`.

# %%
normalized_petals = petal_length / max_petal
#Afficher 5 premieres lignes
print(normalized_petals[:5])
# Out:
# [0.20289855 0.20289855 0.1884058  0.2173913  0.20289855]

# %% [markdown]
# ### B10. Somme cumulée
# Calculez la somme cumulée des largeurs des pétales pour Versicolor.
# Affichez les 10 premières valeurs.

# %%
# petal_Width derniere colonne de features
somme_cumulee = np.cumsum(features[50:100, -1])
print(somme_cumulee[:10])
# Out:
# [ 1.4  2.9  4.4  5.7  7.2  8.5 10.1 11.1 12.4 13.8]

# %% [markdown]
# ### B10. Somme cumulée
# Calculez la somme cumulée des largeurs des pétales pour Versicolor.
# Affichez les 10 premières valeurs.

# %%
# petal_Width derniere colonne de features
somme_cumulee = np.cumsum(features[50:100, -1])
print(somme_cumulee[:10])
# Out:
# [ 1.4  2.9  4.4  5.7  7.2  8.5 10.1 11.1 12.4 13.8]

# %% [markdown]
# # Partie C — Transformations Avancées avec NumPy

# %% [markdown]
# ### C11. Espèces uniques
# Listez les espèces uniques avec `np.unique` et comptez leurs occurrences.

# %%
esp_uniques,n_occ=np.unique(species,return_counts=True)
print(f"Les especes uniques sont :{esp_uniques}")
print(f"Nbre d'occurences est :{n_occ}")
# Out:
# Les especes uniques sont :['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# Nbre d'occurences est :[50 50 50]

# %% [markdown]
# ### C12. Reshape par espèce
# Transformez `features` en un array de forme `(3, 50, 4)` nommé `features_by_species`.

# %%
#shape initial (150,4),150 = 30 x 5
features_by_species=features.reshape(3,50,4)
print(f"Dimension des features_by_species : {features_by_species.shape}")
# Out:
# Dimension des features_by_species : (3, 50, 4)

# %% [markdown]
# ### C13. Concaténation
# Concaténez horizontalement les moyennes par colonne avec un array de zéros.

# %%
zeros=np.zeros(moyennes_col.shape)
concat = np.hstack((moyennes_col,zeros))
print("Resultat de concatenation :")
concat
# Out:
# Resultat de concatenation :
# array([5.84333333, 3.054     , 3.75866667, 1.19866667, 0.        ,
#        0.        , 0.        , 0.        ])

# %% [markdown]
# ### C14. Data cleaning (simulation)
# Simulez des valeurs NaN et remplacez-les avec `np.nan_to_num`.

# %%
liste = np.array([5, 3, np.nan, 4, 3, np.nan, 5, 3.2, 1, 0])
liste_modifiee=np.nan_to_num(liste)
print(liste_modifiee)
# Out:
# [5.  3.  0.  4.  3.  0.  5.  3.2 1.  0. ]

# %% [markdown]
# ### C15. Broadcasting
# Ajoutez 1 à toutes les valeurs de la première colonne de `features`.

# %%
features_apres=features.copy()
features_apres[:,0] += 1
print("2 premieres lignes de features :")
print(features[:2])
print("2 premieres lignes de features_apres :")
features_apres[:2]
# Out:
# 2 premieres lignes de features :
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]]
# 2 premieres lignes de features_apres :
# array([[6.1, 3.5, 1.4, 0.2],
#        [5.9, 3. , 1.4, 0.2]])

# %% [markdown]
# ### C16. np.where
# Créez un array binaire indiquant si la longueur des pétales est supérieure à 4.0.

# %%
binaire=np.where(petal_length > 4 , 1, 0)# si condition verifiée return 1
print("5 premieres lignes de petal_length :")
print(petal_length[:5])
print("5 premieres lignes de binaire :")
binaire[:5]
# Out:
# 5 premieres lignes de petal_length :
# [1.4 1.4 1.3 1.5 1.4]
# 5 premieres lignes de binaire :
# array([0, 0, 0, 0, 0])

# %% [markdown]
# # Partie D — Visualisation avec Matplotlib (Plots Simples)

# %% [markdown]
# ### D17. Line plot
# Line plot des longueurs des sépales pour les 50 premières fleurs.

# %%
import matplotlib.pyplot as plt
x=np.arange(50)  # indices 0 --> 50
y=sepal_length[:50] # 50 entrées
plt.plot(x,y) #  indices vs sepal_length
plt.title("Longueur des sépales")
plt.savefig("figures/d17.jpg")
plt.show()

# %% [markdown]
# ### D18. Scatter plot
# Scatter plot : longueur vs largeur des pétales.

# %%
x=petal_length
y=features[: ,-1] #largeur : derniere colonne de features
plt.scatter(x,y)
plt.title("Longueur vs largeur des pétales")
plt.savefig("figures/d18.jpg")
plt.show()

# %% [markdown]
# ### D19. Bar chart
# Bar chart des moyennes des quatre caractéristiques.

# %%
x=["sepal_length","sepal_width","petal_length","petal_width"] #noms des features
y=moyennes_col #moyennes par colonnes
plt.bar(x,y)
plt.title("Moyennes")
plt.savefig("figures/d19.jpg")
plt.show()

# %% [markdown]
# ### D20. Histogram
# Histogramme de la largeur des sépales (10 bins).

# %%
plt.hist(features[:,1],bins=10)
plt.title("Histogramme de largeur des sepales")
plt.savefig("figures/d20.jpg")
plt.show()

# %% [markdown]
# ### D21. Boxplot par espèce
# Boxplot des longueurs des pétales par espèce.

# %%
#creation liste de tableaux : longueur pour chaque espece
list_tab=[]
for s in esp_uniques :
 petal_array=petal_length[species==s] #tab pour chaque espece
 list_tab.append(petal_array)
#Boxplot
plt.boxplot(list_tab,labels=esp_uniques)
plt.title("Boxplot des longueurs des petales par espece")
plt.show()
plt.savefig("figures/d21.jpg")
# Out:
# /tmp/ipython-input-2804190143.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(list_tab,labels=esp_uniques)

# %% [markdown]
# # Partie E — Visualisations Avancées

# %% [markdown]
# ### E22. Subplots comparatifs
# Deux scatter plots côte à côte : Setosa vs Versicolor.

# %%
fig=plt.figure(figsize=(10,5))
sc1=fig.add_subplot(1,2,1)
sc2=fig.add_subplot(1,2,2)
#Setosa
setosa_array=features_by_species[0]
sc1.scatter(setosa_array[:,0],setosa_array[:,1],color='green')  #features choisis sepal_length et sepal_width
sc1.set_title("Setosa : Largeur vs Longueur sepales")
sc1.set_xlabel("Longueur")
sc1.set_ylabel("Largeur")
#Versicolor
ver_array=features_by_species[1]
sc2.scatter(ver_array[:,0],ver_array[:,1],color='blue')
sc2.set_title("Versicolor : Largeur vs Longueur sepales")
sc2.set_xlabel("Longueur")
sc2.set_ylabel("Largeur")
plt.savefig("figures/e22.jpg")
plt.show()

# %% [markdown]
# ### E23. Grille 2x2
# Histogrammes des 4 caractéristiques avec `plt.subplots(2,2)`.

# %%
fig,axs=plt.subplots(2,2,figsize=(10,10))
#Longueur sepales
axs[0,0].hist(features[:,0],bins=10)
axs[0,0].set_title("Longueur sepales")
#Largeur sepales
axs[0,1].hist(features[:,1],bins=10)
axs[0,1].set_title("Largeur sepales")
#Longueur pétales
axs[1,0].hist(features[:,2],bins=10)
axs[1,0].set_title("Longueur pétales")
#Largeur pétale
axs[1,1].hist(features[:,3],bins=10)
axs[1,1].set_title("Largeur pétales")
plt.savefig("figures/e23.jpg")
plt.show()

# %% [markdown]
# ### E24. Bar chart avec error bars
# Moyennes par espèce avec écart-type.

# %%
#Calcul des moyennes/espece  lignes=especes , col=moy par features
moy_esp=np.mean(features_by_species,axis=1) # Par ligne axis=1
#Calcul d'ecart_type
ecart_type=np.std(features_by_species,axis=1)
#Bar chart
plt.bar(esp_uniques,moy_esp[:,1],yerr=ecart_type[:,1]) #2eme colonne Sepal_width pour les especes
plt.title("Moyennes de sepal_width par espèce avec error bars")
plt.xlabel("Especes")
plt.ylabel("Moyennes")
plt.savefig("figures/e24.jpg")
plt.show()

# %% [markdown]
# ### E25. Scatter coloré par espèce
# Scatter plot avec couleurs par espèce.

# %%
fig,ax=plt.subplots(figsize=(10,5))
#features choisis sepal_length et sepal_width
#setosa
ax.scatter(setosa_array[:,0],setosa_array[:,1],color='green')
# versicolor
ax.scatter(ver_array[:,0],ver_array[:,1],color='blue')
#Virginica
vir_array=features_by_species[2]
ax.scatter(vir_array[:,0],vir_array[:,1],color='red')
ax.set_title("Largeur vs Longueur sepales")
ax.set_xlabel("Longueur")
ax.set_ylabel("Largeur")
plt.legend(esp_uniques)
plt.savefig("figures/e25.jpg")
plt.show()

# %% [markdown]
# ### E26. Line plot superposé
# Cumsum des largeurs des pétales par espèce.

# %%
plt.plot(np.cumsum(setosa_array[:,-1]),color='green',label='Setosa') #derniere colonne
plt.plot(np.cumsum(ver_array[:,-1]),color='blue',label='Versicolor')
plt.plot(np.cumsum(vir_array[:,-1]),color='red',label='Virginica')
plt.title("Cumsum des largeurs des pétales par espèce")
plt.xlabel("Entrée")
plt.ylabel("Cumsum")
plt.legend()
plt.savefig("figures/e26.jpg")
plt.show()

# %% [markdown]
# # Partie F — Mini-Analyse Finale

# %% [markdown]
# ### F27. Corrélations
# Calculez la matrice de corrélation avec `np.corrcoef`.

# %%
#matrice de corrélation des features
matrice_corr=np.corrcoef(features,rowvar=False) #variables en colonnes
print(matrice_corr)
# Out:
# [[ 1.         -0.10936925  0.87175416  0.81795363]
#  [-0.10936925  1.         -0.4205161  -0.35654409]
#  [ 0.87175416 -0.4205161   1.          0.9627571 ]
#  [ 0.81795363 -0.35654409  0.9627571   1.        ]]

# %% [markdown]
# ### F28. Visualisation des corrélations
# Visualisez les corrélations sous forme de bar chart ou scatter.

# %%
x=["sepal_length","sepal_width","petal_length","petal_width"]
y=matrice_corr[0] # correlations de 1er feature avec le reste
plt.bar(x,y)
plt.title("Les corrélations entre sepal_length et les autres features")
plt.savefig("figures/f28.jpg")
plt.show()

# %% [markdown]
# ### F29. Variance par espèce
# Identifiez l’espèce avec la plus grande variance globale et visualisez ses distributions.

# %%
#variances des especes
variances=np.var(features_by_species,axis=1) #variance par espece
vars_glob=np.mean(variances,axis=1)
print(f"Variances globales : {vars_glob.round(4)}")
#espece avec plus grande var glob
indice_max=np.argmax(vars_glob)
print(f"Indice de l'espece avec plus grande variance globale : {indice_max}")
esp_max=esp_uniques[indice_max]
print(f"Espece avec plus grande variance globale : {esp_max}")
# Out:
# Variances globales : [0.0762 0.1531 0.2177]
# Indice de l'espece avec plus grande variance globale : 2
# Espece avec plus grande variance globale : Iris-virginica

# %% [markdown]
# ### F30. Conclusion
# Rédigez une conclusion contenant **3 insights** issus de votre analyse.

# %% [markdown]
# 1) D'apres la matrice de correlation , longueur des sepales est fortement correlé avec longueur et largeur petales dont ils augmentent à la fois
# 2) La largeur des sepales  est negativement et faiblement  corrélé coef = -0,1 donc evolue toute seule .
# 3) Les valeurs des features de l'espece Virginica sont très dispersés
